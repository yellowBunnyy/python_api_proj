# %%
import numpy as np
import pandas as pd
import download_urls
import extract_data

# %%
df = extract_data.main()
# Out:
# /home/seb/Desktop/py/study_wsb/python_api_proj/data_scraper/download_urls.py:27: GuessedAtParserWarning: No parser was explicitly specified, so I'm using the best available HTML parser for this system ("html.parser"). This usually isn't a problem, but if you run this code on another system, or in a different virtual environment, it may use a different parser and behave differently.
#
# The code that caused this warning is on line 27 of the file /home/seb/Desktop/py/study_wsb/python_api_proj/data_scraper/download_urls.py. To get rid of this warning, pass the additional argument 'features="html.parser"' to the BeautifulSoup constructor.
#
#   soup = BeautifulSoup(req.text)
# Processed url http://wwwold.pzh.gov.pl/oldpage/epimeld/grypa/2020/G_20_01A.pdf !
# 1 do 7 stycznia 2020 r
# Processed url http://wwwold.pzh.gov.pl/oldpage/epimeld/grypa/2020/G_20_01B.pdf !
# 8 do 15 stycznia 2020 r
# Processed url http://wwwold.pzh.gov.pl/oldpage/epimeld/grypa/2020/G_20_01C.pdf !
# ...

# %%
df.to_csv("./influenza.csv")
f = pd.read_csv('influenza.csv')

# %%
f
# Out:
#        Unnamed: 0  Confirmed  Hospitalized  Deaths
# 0      1-7-1-2020      89211           393       0
# 1     8-15-1-2020     122430           498       3
# 2    16-22-1-2020     127696           615       2
# 3    23-31-1-2020     204726          1286       5
# 4      1-7-2-2020     193482          1103       2
# 5     8-15-2-2020     200194          1325       4
# 6    16-22-2-2020     211983          1582       9
# 7    23-29-2-2020     215994          1586       8
# 8      1-7-3-2020     211572          1546       7
# 9     8-15-3-2020     158677          1228       7
# 10   16-22-3-2020     109281           529       0
# 11   23-31-3-2020     102272           483       6
# 12     1-7-4-2020      53568           168       4
# 13    8-15-4-2020      35400           150       1
# 14   16-22-4-2020      24021           120       0
# 15   23-30-4-2020      19541            71       3
# 16     1-7-5-2020      14441           116       1
# ...
